# %% [markdown]
# ### 1. A

# %%
import threading
import time
import random
import logging

BUFFER_SIZE = 30
PRODUCER_SLEEP_MIN = 1.0
PRODUCER_SLEEP_MAX = 3.0
CONSUMER_SLEEP_MIN = 1.0
CONSUMER_SLEEP_MAX = 3.0
RUN_DURATION = 20
NUM_CONSUMERS = 5

LOG_FORMAT = '%(threadName)-17s %(levelname)-8s %(message)s'
logging.basicConfig(level=logging.INFO, format=LOG_FORMAT)

buffer = []
buffer_lock = threading.Lock()
empty_slots = threading.Semaphore(BUFFER_SIZE)
filled_slots = threading.Semaphore(0)

stop_threads = False

def producer(first, last):
    global stop_threads
    item_id = 0
    while not stop_threads:
        sleep_time = random.uniform(first, last)
        time.sleep(sleep_time)

        acquired = empty_slots.acquire(timeout=1)
        if not acquired:
            logging.info("Producer: Timeout waiting for empty slot.")
            continue

        if stop_threads:
            empty_slots.release()
            break

        item = f"item-{item_id}"
        with buffer_lock:
            buffer.append(item)
            logging.info(f"Produced: {item}")
            item_id += 1

        filled_slots.release()

    logging.info("Producer stopping...")

def consumer(consumer_id, first, last):
    global stop_threads
    while not stop_threads:
        sleep_time = random.uniform(first, last)
        time.sleep(sleep_time)

        acquired = filled_slots.acquire(timeout=1)
        if not acquired:
            if stop_threads:
                break
            logging.info(f"Consumer {consumer_id}: Timeout waiting for items.")
            continue

        if stop_threads:
            filled_slots.release()
            break

        with buffer_lock:
            if buffer:
                item = buffer.pop(0)
                logging.info(f"Consumer {consumer_id} consumed: {item}")
            else:
                logging.info(f"Consumer {consumer_id}: Buffer was empty after acquiring semaphore.")
                filled_slots.release()
                continue

        empty_slots.release()

    logging.info(f"Consumer {consumer_id} stopping...")

def timer_thread(duration):
    global stop_threads
    time.sleep(duration)
    stop_threads = True
    logging.info("Timer finished, requesting all threads to stop...")

def main():
    t_producer = threading.Thread(target=producer, args=(PRODUCER_SLEEP_MIN, PRODUCER_SLEEP_MAX), name="Producer")
    t_producer.start()

    consumers = []
    for i in range(NUM_CONSUMERS):
        t = threading.Thread(target=consumer, args=(i, CONSUMER_SLEEP_MIN, CONSUMER_SLEEP_MAX), name=f"Consumer-{i}")
        t.start()
        consumers.append(t)

    t_timer = threading.Thread(target=timer_thread, args=(RUN_DURATION,), name="Timer")
    t_timer.start()

    t_timer.join()
    t_producer.join()
    for t in consumers:
        t.join()

    logging.info("All threads terminated, program finished.")

if __name__ == "__main__":
    main()
# Out:
# Producer          INFO     Produced: item-0
# Consumer-2        INFO     Consumer 2 consumed: item-0
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Producer          INFO     Produced: item-1
# Consumer-1        INFO     Consumer 1 consumed: item-1
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Producer          INFO     Produced: item-2
# Consumer-3        INFO     Consumer 3 consumed: item-2
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Producer          INFO     Produced: item-3
# Consumer-4        INFO     Consumer 4 consumed: item-3
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Producer          INFO     Produced: item-4
# Consumer-2        INFO     Consumer 2 consumed: item-4
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Producer          INFO     Produced: item-5
# Consumer-1        INFO     Consumer 1 consumed: item-5
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Producer          INFO     Produced: item-6
# Consumer-2        INFO     Consumer 2 consumed: item-6
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Producer          INFO     Produced: item-7
# Consumer-4        INFO     Consumer 4 consumed: item-7
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Producer          INFO     Produced: item-8
# Consumer-2        INFO     Consumer 2 consumed: item-8
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Producer          INFO     Produced: item-9
# Consumer-3        INFO     Consumer 3 consumed: item-9
# Timer             INFO     Timer finished, requesting all threads to stop...
# Consumer-4        INFO     Consumer 4 stopping...
# Consumer-1        INFO     Consumer 1 stopping...
# Consumer-2        INFO     Consumer 2 stopping...
# Producer          INFO     Producer stopping...
# Consumer-0        INFO     Consumer 0 stopping...
# Consumer-3        INFO     Consumer 3 stopping...
# MainThread        INFO     All threads terminated, program finished.

# %% [markdown]
# # 1.B

# %%
BUFFER_SIZE = 30
PRODUCER_SLEEP_MIN = 0.1
PRODUCER_SLEEP_MAX = 0.3
CONSUMER_SLEEP_MIN = 3.0
CONSUMER_SLEEP_MAX = 4.0
RUN_DURATION = 20
NUM_CONSUMERS = 5

LOG_FORMAT = '%(threadName)-17s %(levelname)-8s %(message)s'
logging.basicConfig(level=logging.INFO, format=LOG_FORMAT)

buffer = []
buffer_lock = threading.Lock()
empty_slots = threading.Semaphore(BUFFER_SIZE)
filled_slots = threading.Semaphore(0)

stop_threads = False
def main():
    t_producer = threading.Thread(target=producer, args=(PRODUCER_SLEEP_MIN, PRODUCER_SLEEP_MAX), name="Producer")
    t_producer.start()

    consumers = []
    for i in range(NUM_CONSUMERS):
        t = threading.Thread(target=consumer, args=(i, CONSUMER_SLEEP_MIN, CONSUMER_SLEEP_MAX), name=f"Consumer-{i}")
        t.start()
        consumers.append(t)

    t_timer = threading.Thread(target=timer_thread, args=(RUN_DURATION,), name="Timer")
    t_timer.start()

    t_timer.join()
    t_producer.join()
    for t in consumers:
        t.join()

    logging.info("All threads terminated, program finished.")

if __name__ == "__main__":
    main()
# Out:
# Producer          INFO     Produced: item-0
# Producer          INFO     Produced: item-1
# Producer          INFO     Produced: item-2
# Producer          INFO     Produced: item-3
# Producer          INFO     Produced: item-4
# Producer          INFO     Produced: item-5
# Producer          INFO     Produced: item-6
# Producer          INFO     Produced: item-7
# Producer          INFO     Produced: item-8
# Producer          INFO     Produced: item-9
# Producer          INFO     Produced: item-10
# Producer          INFO     Produced: item-11
# Producer          INFO     Produced: item-12
# Producer          INFO     Produced: item-13
# Producer          INFO     Produced: item-14
# Consumer-4        INFO     Consumer 4 consumed: item-0
# Producer          INFO     Produced: item-15
# Consumer-2        INFO     Consumer 2 consumed: item-1
# Producer          INFO     Produced: item-16
# Consumer-3        INFO     Consumer 3 consumed: item-2
# Consumer-0        INFO     Consumer 0 consumed: item-3
# Producer          INFO     Produced: item-17
# Consumer-1        INFO     Consumer 1 consumed: item-4
# Producer          INFO     Produced: item-18
# Producer          INFO     Produced: item-19
# Producer          INFO     Produced: item-20
# Producer          INFO     Produced: item-21
# Producer          INFO     Produced: item-22
# Producer          INFO     Produced: item-23
# Producer          INFO     Produced: item-24
# Producer          INFO     Produced: item-25
# Producer          INFO     Produced: item-26
# Producer          INFO     Produced: item-27
# Producer          INFO     Produced: item-28
# Consumer-4        INFO     Consumer 4 consumed: item-5
# Producer          INFO     Produced: item-29
# Producer          INFO     Produced: item-30
# Producer          INFO     Produced: item-31
# Consumer-0        INFO     Consumer 0 consumed: item-6
# Producer          INFO     Produced: item-32
# Consumer-3        INFO     Consumer 3 consumed: item-7
# Consumer-2        INFO     Consumer 2 consumed: item-8
# Producer          INFO     Produced: item-33
# Consumer-1        INFO     Consumer 1 consumed: item-9
# Producer          INFO     Produced: item-34
# Producer          INFO     Produced: item-35
# Producer          INFO     Produced: item-36
# Producer          INFO     Produced: item-37
# Producer          INFO     Produced: item-38
# Producer          INFO     Produced: item-39
# Producer          INFO     Producer: Timeout waiting for empty slot.
# Consumer-4        INFO     Consumer 4 consumed: item-10
# Producer          INFO     Produced: item-40
# Consumer-2        INFO     Consumer 2 consumed: item-11
# Consumer-3        INFO     Consumer 3 consumed: item-12
# Consumer-1        INFO     Consumer 1 consumed: item-13
# Producer          INFO     Produced: item-41
# Producer          INFO     Produced: item-42
# Consumer-0        INFO     Consumer 0 consumed: item-14
# Producer          INFO     Produced: item-43
# Producer          INFO     Produced: item-44
# Producer          INFO     Producer: Timeout waiting for empty slot.
# Producer          INFO     Producer: Timeout waiting for empty slot.
# Consumer-3        INFO     Consumer 3 consumed: item-15
# Producer          INFO     Produced: item-45
# Consumer-2        INFO     Consumer 2 consumed: item-16
# Consumer-4        INFO     Consumer 4 consumed: item-17
# Consumer-0        INFO     Consumer 0 consumed: item-18
# Consumer-1        INFO     Consumer 1 consumed: item-19
# Producer          INFO     Produced: item-46
# Producer          INFO     Produced: item-47
# Producer          INFO     Produced: item-48
# Producer          INFO     Produced: item-49
# Producer          INFO     Producer: Timeout waiting for empty slot.
# Producer          INFO     Producer: Timeout waiting for empty slot.
# Consumer-2        INFO     Consumer 2 consumed: item-20
# Consumer-4        INFO     Consumer 4 consumed: item-21
# Producer          INFO     Produced: item-50
# Consumer-0        INFO     Consumer 0 consumed: item-22
# Producer          INFO     Produced: item-51
# Producer          INFO     Produced: item-52
# Consumer-3        INFO     Consumer 3 consumed: item-23
# Consumer-1        INFO     Consumer 1 consumed: item-24
# Producer          INFO     Produced: item-53
# Producer          INFO     Produced: item-54
# Producer          INFO     Producer: Timeout waiting for empty slot.
# Timer             INFO     Timer finished, requesting all threads to stop...
# Consumer-2        INFO     Consumer 2 stopping...
# Consumer-0        INFO     Consumer 0 stopping...
# Producer          INFO     Producer: Timeout waiting for empty slot.
# Producer          INFO     Producer stopping...
# Consumer-3        INFO     Consumer 3 stopping...
# Consumer-4        INFO     Consumer 4 stopping...
# Consumer-1        INFO     Consumer 1 stopping...
# MainThread        INFO     All threads terminated, program finished.

# %% [markdown]
# # 1.C

# %%
BUFFER_SIZE = 30
PRODUCER_SLEEP_MIN = 0.2
PRODUCER_SLEEP_MAX = 0.5
CONSUMER_SLEEP_MIN = 1.5
CONSUMER_SLEEP_MAX = 3.0
RUN_DURATION = 20
NUM_CONSUMERS = 5

LOG_FORMAT = '%(threadName)-17s %(levelname)-8s %(message)s'
logging.basicConfig(level=logging.INFO, format=LOG_FORMAT)

buffer = []
buffer_lock = threading.Lock()
empty_slots = threading.Semaphore(BUFFER_SIZE)
filled_slots = threading.Semaphore(0)

stop_threads = False
def main():
    t_producer = threading.Thread(target=producer, args=(PRODUCER_SLEEP_MIN, PRODUCER_SLEEP_MAX), name="Producer")
    t_producer.start()

    consumers = []
    for i in range(NUM_CONSUMERS):
        t = threading.Thread(target=consumer, args=(i, CONSUMER_SLEEP_MIN, CONSUMER_SLEEP_MAX), name=f"Consumer-{i}")
        t.start()
        consumers.append(t)

    t_timer = threading.Thread(target=timer_thread, args=(RUN_DURATION,), name="Timer")
    t_timer.start()

    t_timer.join()
    t_producer.join()
    for t in consumers:
        t.join()

    logging.info("All threads terminated, program finished.")

if __name__ == "__main__":
    main()
# Out:
# Producer          INFO     Produced: item-0
# Producer          INFO     Produced: item-1
# Producer          INFO     Produced: item-2
# Producer          INFO     Produced: item-3
# Consumer-0        INFO     Consumer 0 consumed: item-0
# Consumer-1        INFO     Consumer 1 consumed: item-1
# Consumer-3        INFO     Consumer 3 consumed: item-2
# Producer          INFO     Produced: item-4
# Consumer-4        INFO     Consumer 4 consumed: item-3
# Consumer-2        INFO     Consumer 2 consumed: item-4
# Producer          INFO     Produced: item-5
# Producer          INFO     Produced: item-6
# Consumer-1        INFO     Consumer 1 consumed: item-5
# Producer          INFO     Produced: item-7
# Producer          INFO     Produced: item-8
# Consumer-3        INFO     Consumer 3 consumed: item-6
# Consumer-0        INFO     Consumer 0 consumed: item-7
# Producer          INFO     Produced: item-9
# Consumer-4        INFO     Consumer 4 consumed: item-8
# Producer          INFO     Produced: item-10
# Consumer-2        INFO     Consumer 2 consumed: item-9
# Producer          INFO     Produced: item-11
# Producer          INFO     Produced: item-12
# Consumer-1        INFO     Consumer 1 consumed: item-10
# Producer          INFO     Produced: item-13
# Producer          INFO     Produced: item-14
# Producer          INFO     Produced: item-15
# Consumer-0        INFO     Consumer 0 consumed: item-11
# Consumer-3        INFO     Consumer 3 consumed: item-12
# Producer          INFO     Produced: item-16
# Producer          INFO     Produced: item-17
# Consumer-4        INFO     Consumer 4 consumed: item-13
# Producer          INFO     Produced: item-18
# Producer          INFO     Produced: item-19
# Consumer-2        INFO     Consumer 2 consumed: item-14
# Producer          INFO     Produced: item-20
# Consumer-0        INFO     Consumer 0 consumed: item-15
# Producer          INFO     Produced: item-21
# Consumer-1        INFO     Consumer 1 consumed: item-16
# Consumer-3        INFO     Consumer 3 consumed: item-17
# Producer          INFO     Produced: item-22
# Producer          INFO     Produced: item-23
# Consumer-4        INFO     Consumer 4 consumed: item-18
# Consumer-2        INFO     Consumer 2 consumed: item-19
# Producer          INFO     Produced: item-24
# Producer          INFO     Produced: item-25
# Producer          INFO     Produced: item-26
# Producer          INFO     Produced: item-27
# Producer          INFO     Produced: item-28
# Consumer-1        INFO     Consumer 1 consumed: item-20
# Consumer-4        INFO     Consumer 4 consumed: item-21
# Producer          INFO     Produced: item-29
# Consumer-0        INFO     Consumer 0 consumed: item-22
# Producer          INFO     Produced: item-30
# Consumer-3        INFO     Consumer 3 consumed: item-23
# Producer          INFO     Produced: item-31
# Producer          INFO     Produced: item-32
# Producer          INFO     Produced: item-33
# Consumer-2        INFO     Consumer 2 consumed: item-24
# Producer          INFO     Produced: item-34
# Consumer-0        INFO     Consumer 0 consumed: item-25
# Consumer-4        INFO     Consumer 4 consumed: item-26
# Producer          INFO     Produced: item-35
# Producer          INFO     Produced: item-36
# Consumer-1        INFO     Consumer 1 consumed: item-27
# Producer          INFO     Produced: item-37
# Consumer-3        INFO     Consumer 3 consumed: item-28
# Consumer-2        INFO     Consumer 2 consumed: item-29
# Producer          INFO     Produced: item-38
# Consumer-4        INFO     Consumer 4 consumed: item-30
# Producer          INFO     Produced: item-39
# Producer          INFO     Produced: item-40
# Consumer-0        INFO     Consumer 0 consumed: item-31
# Producer          INFO     Produced: item-41
# Producer          INFO     Produced: item-42
# Consumer-1        INFO     Consumer 1 consumed: item-32
# Producer          INFO     Produced: item-43
# Consumer-2        INFO     Consumer 2 consumed: item-33
# Consumer-3        INFO     Consumer 3 consumed: item-34
# Producer          INFO     Produced: item-44
# Producer          INFO     Produced: item-45
# Producer          INFO     Produced: item-46
# Consumer-4        INFO     Consumer 4 consumed: item-35
# Producer          INFO     Produced: item-47
# Consumer-0        INFO     Consumer 0 consumed: item-36
# Producer          INFO     Produced: item-48
# Producer          INFO     Produced: item-49
# Consumer-1        INFO     Consumer 1 consumed: item-37
# Consumer-2        INFO     Consumer 2 consumed: item-38
# Producer          INFO     Produced: item-50
# Consumer-4        INFO     Consumer 4 consumed: item-39
# Consumer-3        INFO     Consumer 3 consumed: item-40
# Producer          INFO     Produced: item-51
# Producer          INFO     Produced: item-52
# Producer          INFO     Produced: item-53
# Consumer-0        INFO     Consumer 0 consumed: item-41
# Timer             INFO     Timer finished, requesting all threads to stop...
# Producer          INFO     Producer stopping...
# Consumer-1        INFO     Consumer 1 stopping...
# Consumer-4        INFO     Consumer 4 stopping...
# Consumer-3        INFO     Consumer 3 stopping...
# Consumer-2        INFO     Consumer 2 stopping...
# Consumer-0        INFO     Consumer 0 stopping...
# MainThread        INFO     All threads terminated, program finished.

# %% [markdown]
# # 1.A

# %%
import threading
import queue
import time
import random

BUFFER_SIZE = 30
q = queue.Queue(BUFFER_SIZE)
stop_threads = False
def producer(first, last):
    item_id = 0
    while True:
        if stop_threads:
            print("Producer stopping...")
            break
        
        time.sleep(random.uniform(first, last))
        item = f"item-{item_id}"
        if not q.full():
            q.put(item, timeout=1)
            print(f"Produced: {item}")
            item_id += 1
        else:
            print(f"producer: queue is full, waiting for 1 second")
            time.sleep(1)


def consumer(consumer_id, first, last):
    while True:
        if stop_threads:
            print(f"Consumer {consumer_id} stopping...")
            break
        
        time.sleep(random.uniform(first, last))
        if not q.empty():
                
            item = q.get(timeout=1)
            print(f"Consumer {consumer_id} consumed: {item}")
            q.task_done()
        else:

            print(f"Consumer {consumer_id} queue is empty, waiting for 1 second")
            time.sleep(1)


def timer_thread(duration):
    time.sleep(duration)
    global stop_threads
    stop_threads = True
    print("Timer finished, requesting all threads to stop...")


if __name__ == "__main__":
    t_producer = threading.Thread(target=producer, args=(1., 3.,))
    t_producer.start()

    consumers = []
    for i in range(5):
        t = threading.Thread(target=consumer, args=(i, 1.0, 3.0,))
        t.start()
        consumers.append(t)

    t_timer = threading.Thread(target=timer_thread, args=(20,))
    t_timer.start()

    t_producer.join()
    for t in consumers:
        t.join()
    t_timer.join()

    print("All threads terminated, program finished.")
# Out:
# Consumer 3 queue is empty, waiting for 1 second
# Consumer 0 queue is empty, waiting for 1 second
# Consumer 4 queue is empty, waiting for 1 second
# Produced: item-0
# Consumer 2 consumed: item-0
# Consumer 1 queue is empty, waiting for 1 second
# Produced: item-1
# Consumer 3 consumed: item-1
# Consumer 2 queue is empty, waiting for 1 second
# Consumer 0 queue is empty, waiting for 1 second
# Consumer 3 queue is empty, waiting for 1 second
# Consumer 4 queue is empty, waiting for 1 second
# Consumer 1 queue is empty, waiting for 1 second
# Produced: item-2
# Consumer 2 consumed: item-2
# Consumer 3 queue is empty, waiting for 1 second
# Consumer 0 queue is empty, waiting for 1 second
# Consumer 1 queue is empty, waiting for 1 second
# Consumer 4 queue is empty, waiting for 1 second
# Produced: item-3
# Consumer 2 consumed: item-3
# Consumer 0 queue is empty, waiting for 1 second
# Consumer 3 queue is empty, waiting for 1 second
# Produced: item-4
# Consumer 1 consumed: item-4
# Consumer 2 queue is empty, waiting for 1 second
# Consumer 4 queue is empty, waiting for 1 second
# Consumer 0 queue is empty, waiting for 1 second
# Produced: item-5
# Consumer 1 consumed: item-5
# Consumer 3 queue is empty, waiting for 1 second
# Consumer 4 queue is empty, waiting for 1 second
# Produced: item-6
# Consumer 2 consumed: item-6
# Consumer 1 queue is empty, waiting for 1 second
# Consumer 0 queue is empty, waiting for 1 second
# Consumer 3 queue is empty, waiting for 1 second
# Consumer 2 queue is empty, waiting for 1 second
# Produced: item-7
# Consumer 4 consumed: item-7
# Consumer 1 queue is empty, waiting for 1 second
# Produced: item-8
# Consumer 0 consumed: item-8
# Consumer 2 queue is empty, waiting for 1 second
# Consumer 3 queue is empty, waiting for 1 second
# Consumer 4 queue is empty, waiting for 1 second
# Timer finished, requesting all threads to stop...
# Consumer 2 stopping...
# Consumer 0 queue is empty, waiting for 1 second
# Consumer 3 stopping...Consumer 1 queue is empty, waiting for 1 second
#
# Consumer 4 stopping...
# Produced: item-9
# Producer stopping...
# Consumer 0 stopping...
# Consumer 1 stopping...
# All threads terminated, program finished.

# %% [markdown]
# ### 1. B

# %%
stop_threads = False
q = queue.Queue(BUFFER_SIZE)
if __name__ == "__main__":
    t_producer = threading.Thread(target=producer, args=(0.1, 0.3,))
    t_producer.start()

    consumers = []
    for i in range(5):
        t = threading.Thread(target=consumer, args=(i, 3.0, 4.0,))
        t.start()
        consumers.append(t)

    t_timer = threading.Thread(target=timer_thread, args=(20,))
    t_timer.start()

    t_producer.join()
    for t in consumers:
        t.join()
    t_timer.join()

    print("All threads terminated, program finished.")
# Out:
# Produced: item-0
# Produced: item-1
# Produced: item-2
# Produced: item-3
# Produced: item-4
# Produced: item-5
# Produced: item-6
# Produced: item-7
# Produced: item-8
# Produced: item-9
# Produced: item-10
# Produced: item-11
# Produced: item-12
# Produced: item-13
# Produced: item-14
# Produced: item-15
# Consumer 3 consumed: item-0
# Produced: item-16
# Consumer 0 consumed: item-1
# Consumer 4 consumed: item-2
# Produced: item-17
# Produced: item-18
# Consumer 2 consumed: item-3
# Consumer 1 consumed: item-4
# Produced: item-19
# Produced: item-20
# Produced: item-21
# Produced: item-22
# Produced: item-23
# Produced: item-24
# Produced: item-25
# Produced: item-26
# Produced: item-27
# Produced: item-28
# Produced: item-29
# Produced: item-30
# Consumer 4 consumed: item-5
# Produced: item-31
# Produced: item-32
# Consumer 2 consumed: item-6
# Consumer 3 consumed: item-7
# Consumer 0 consumed: item-8
# Consumer 1 consumed: item-9
# Produced: item-33
# Produced: item-34
# Produced: item-35
# Produced: item-36
# Produced: item-37
# Produced: item-38
# Produced: item-39
# producer: queue is full, waiting for 1 second
# producer: queue is full, waiting for 1 second
# Consumer 4 consumed: item-10
# Consumer 2 consumed: item-11
# Consumer 3 consumed: item-12
# Consumer 0 consumed: item-13
# Produced: item-40
# Consumer 1 consumed: item-14
# Produced: item-41
# Produced: item-42
# Produced: item-43
# Produced: item-44
# producer: queue is full, waiting for 1 second
# producer: queue is full, waiting for 1 second
# Consumer 2 consumed: item-15
# Consumer 4 consumed: item-16
# Consumer 0 consumed: item-17
# Consumer 3 consumed: item-18
# Produced: item-45
# Consumer 1 consumed: item-19
# Produced: item-46
# Produced: item-47
# Produced: item-48
# Produced: item-49
# producer: queue is full, waiting for 1 second
# Consumer 2 consumed: item-20
# Consumer 4 consumed: item-21
# Produced: item-50
# Consumer 0 consumed: item-22
# Produced: item-51
# Consumer 3 consumed: item-23
# Produced: item-52
# Produced: item-53
# producer: queue is full, waiting for 1 second
# Consumer 1 consumed: item-24
# Produced: item-54
# producer: queue is full, waiting for 1 second
# Timer finished, requesting all threads to stop...
# Consumer 2 consumed: item-25
# Consumer 2 stopping...
# Producer stopping...
# Consumer 0 consumed: item-26
# Consumer 0 stopping...
# Consumer 3 consumed: item-27
# Consumer 3 stopping...
# Consumer 4 consumed: item-28
# Consumer 4 stopping...
# Consumer 1 consumed: item-29
# Consumer 1 stopping...
# All threads terminated, program finished.

# %% [markdown]
# ### 1. C

# %%
stop_threads = False
q = queue.Queue(BUFFER_SIZE)

if __name__ == "__main__":
    t_producer = threading.Thread(target=producer, args=(.2, .5,))
    t_producer.start()

    consumers = []
    for i in range(5):
        t = threading.Thread(target=consumer, args=(i, 1.5, 3.0,))
        t.start()
        consumers.append(t)

    t_timer = threading.Thread(target=timer_thread, args=(20,))
    t_timer.start()

    t_producer.join()
    for t in consumers:
        t.join()
    t_timer.join()

    print("All threads terminated, program finished.")
# Out:
# Produced: item-0
# Produced: item-1
# Produced: item-2
# Produced: item-3
# Consumer 3 consumed: item-0
# Consumer 1 consumed: item-1Produced: item-4
#
# Produced: item-5
# Produced: item-6
# Consumer 2 consumed: item-2
# Consumer 0 consumed: item-3
# Consumer 4 consumed: item-4
# Produced: item-7
# Consumer 3 consumed: item-5
# Produced: item-8
# Produced: item-9
# Produced: item-10
# Consumer 1 consumed: item-6
# Produced: item-11
# Produced: item-12
# Produced: item-13
# Produced: item-14
# Consumer 2 consumed: item-7
# Consumer 4 consumed: item-8
# Produced: item-15
# Consumer 3 consumed: item-9
# Consumer 0 consumed: item-10
# Produced: item-16
# Produced: item-17
# Produced: item-18
# Consumer 1 consumed: item-11
# Produced: item-19
# Consumer 2 consumed: item-12
# Produced: item-20
# Produced: item-21Consumer 3 consumed: item-13
#
# Produced: item-22
# Consumer 4 consumed: item-14
# Produced: item-23
# Produced: item-24
# Consumer 0 consumed: item-15
# Consumer 2 consumed: item-16
# Produced: item-25
# Produced: item-26
# Consumer 1 consumed: item-17
# Produced: item-27
# Produced: item-28
# Produced: item-29
# Consumer 4 consumed: item-18
# Consumer 3 consumed: item-19
# Produced: item-30
# Consumer 1 consumed: item-20
# Produced: item-31
# Consumer 0 consumed: item-21
# Produced: item-32
# Consumer 2 consumed: item-22
# Produced: item-33
# Produced: item-34
# Consumer 4 consumed: item-23
# Produced: item-35
# Consumer 3 consumed: item-24
# Produced: item-36
# Consumer 1 consumed: item-25
# Consumer 0 consumed: item-26
# Produced: item-37
# Consumer 2 consumed: item-27
# Produced: item-38
# Consumer 4 consumed: item-28
# Produced: item-39
# Produced: item-40
# Produced: item-41
# Produced: item-42
# Consumer 3 consumed: item-29
# Produced: item-43
# Produced: item-44
# Consumer 0 consumed: item-30
# Consumer 1 consumed: item-31
# Produced: item-45
# Consumer 4 consumed: item-32
# Consumer 2 consumed: item-33
# Produced: item-46
# Produced: item-47
# Produced: item-48
# Produced: item-49
# Consumer 3 consumed: item-34
# Produced: item-50
# Consumer 1 consumed: item-35Produced: item-51
#
# Produced: item-52
# Consumer 2 consumed: item-36
# Consumer 0 consumed: item-37
# Produced: item-53
# Consumer 4 consumed: item-38
# Produced: item-54
# Produced: item-55
# Timer finished, requesting all threads to stop...
# Produced: item-56
# Producer stopping...
# Consumer 3 consumed: item-39
# Consumer 3 stopping...
# Consumer 0 consumed: item-40
# Consumer 0 stopping...
# Consumer 4 consumed: item-41
# Consumer 4 stopping...
# Consumer 1 consumed: item-42
# Consumer 1 stopping...
# Consumer 2 consumed: item-43
# Consumer 2 stopping...
# All threads terminated, program finished.

# %% [markdown]
# ### 2. A

# %%
import logging
import threading
import time
import random

LOG_FORMAT = '%(threadName)-17s %(levelname)-8s %(message)s'
logging.basicConfig(level=logging.INFO, format=LOG_FORMAT)

BUFFER_SIZE = 30
PRODUCER_SLEEP_MIN = 1.0
PRODUCER_SLEEP_MAX = 2.0
CONSUMER_SLEEP_MIN = 0.1
CONSUMER_SLEEP_MAX = 0.5
RUN_DURATION = 20
NUM_CONSUMERS = 5
NUM_PRODUCERS = 3

buffer = []
buffer_lock = threading.Lock()
empty_slots = threading.Semaphore(BUFFER_SIZE)
filled_slots = threading.Semaphore(0)

stop_threads = False

def producer(first, last):
    global stop_threads
    item_id = 0
    while not stop_threads:
        sleep_time = random.uniform(first, last)
        time.sleep(sleep_time)
        acquired = empty_slots.acquire(timeout=1)
        if not acquired:
            logging.info("Producer: Timeout waiting for empty slot.")
            continue
        if stop_threads:
            empty_slots.release()
            break
        item = f"item-{item_id}"
        with buffer_lock:
            buffer.append(item)
            logging.info(f"Produced: {item}")
            item_id += 1
        filled_slots.release()
    logging.info("Producer stopping...")

def consumer(consumer_id, first, last):
    global stop_threads
    while not stop_threads:
        sleep_time = random.uniform(first, last)
        time.sleep(sleep_time)
        acquired = filled_slots.acquire(timeout=1)
        if not acquired:
            if stop_threads:
                break
            logging.info(f"Consumer {consumer_id}: Timeout waiting for items.")
            continue
        if stop_threads:
            filled_slots.release()
            break
        with buffer_lock:
            if buffer:
                item = buffer.pop(0)
                logging.info(f"Consumer {consumer_id} consumed: {item}")
            else:
                logging.info(f"Consumer {consumer_id}: Buffer was empty after acquiring semaphore.")
                filled_slots.release()
                continue
        empty_slots.release()
    logging.info(f"Consumer {consumer_id} stopping...")

def timer_thread(duration):
    global stop_threads
    time.sleep(duration)
    stop_threads = True
    logging.info("Timer finished, requesting all threads to stop...")

def main():
    producers = []
    for i in range(NUM_PRODUCERS):
        t = threading.Thread(target=producer, args=(PRODUCER_SLEEP_MIN, PRODUCER_SLEEP_MAX), name=f"Producer-{i}")
        t.start()
        producers.append(t)
    consumers = []
    for i in range(NUM_CONSUMERS):
        t = threading.Thread(target=consumer, args=(i, CONSUMER_SLEEP_MIN, CONSUMER_SLEEP_MAX), name=f"Consumer-{i}")
        t.start()
        consumers.append(t)
    t_timer = threading.Thread(target=timer_thread, args=(RUN_DURATION,), name="Timer")
    t_timer.start()
    t_timer.join()
    for t in producers:
        t.join()
    for t in consumers:
        t.join()
    logging.info("All threads terminated, program finished.")

if __name__ == "__main__":
    main()
# Out:
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Producer-0        INFO     Produced: item-0
# Consumer-3        INFO     Consumer 3 consumed: item-0
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Producer-2        INFO     Produced: item-0
# Consumer-3        INFO     Consumer 3 consumed: item-0
# Producer-1        INFO     Produced: item-0
# Consumer-1        INFO     Consumer 1 consumed: item-0
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Producer-0        INFO     Produced: item-1
# Consumer-1        INFO     Consumer 1 consumed: item-1
# Producer-1        INFO     Produced: item-1
# Consumer-2        INFO     Consumer 2 consumed: item-1
# Producer-2        INFO     Produced: item-1
# Consumer-0        INFO     Consumer 0 consumed: item-1
# Producer-0        INFO     Produced: item-2
# Consumer-4        INFO     Consumer 4 consumed: item-2
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Producer-1        INFO     Produced: item-2
# Consumer-0        INFO     Consumer 0 consumed: item-2
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Producer-2        INFO     Produced: item-2
# Consumer-3        INFO     Consumer 3 consumed: item-2
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Producer-1        INFO     Produced: item-3
# Consumer-0        INFO     Consumer 0 consumed: item-3
# Producer-0        INFO     Produced: item-3
# Consumer-2        INFO     Consumer 2 consumed: item-3
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Producer-2        INFO     Produced: item-3
# Consumer-0        INFO     Consumer 0 consumed: item-3
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Producer-1        INFO     Produced: item-4
# Consumer-4        INFO     Consumer 4 consumed: item-4
# Producer-0        INFO     Produced: item-4
# Consumer-0        INFO     Consumer 0 consumed: item-4
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Producer-1        INFO     Produced: item-5
# Consumer-2        INFO     Consumer 2 consumed: item-5
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Producer-2        INFO     Produced: item-4
# Consumer-4        INFO     Consumer 4 consumed: item-4
# Producer-0        INFO     Produced: item-5
# Consumer-0        INFO     Consumer 0 consumed: item-5
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Producer-1        INFO     Produced: item-6
# Consumer-2        INFO     Consumer 2 consumed: item-6
# Producer-0        INFO     Produced: item-6
# Producer-2        INFO     Produced: item-5
# Consumer-3        INFO     Consumer 3 consumed: item-6
# Consumer-4        INFO     Consumer 4 consumed: item-5
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Producer-1        INFO     Produced: item-7
# Consumer-3        INFO     Consumer 3 consumed: item-7
# Producer-2        INFO     Produced: item-6
# Consumer-4        INFO     Consumer 4 consumed: item-6
# Producer-0        INFO     Produced: item-7
# Consumer-0        INFO     Consumer 0 consumed: item-7
# Consumer-1        INFO     Consumer 1: Timeout waiting for items.
# Producer-1        INFO     Produced: item-8
# Consumer-3        INFO     Consumer 3 consumed: item-8
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Producer-0        INFO     Produced: item-8
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Consumer-4        INFO     Consumer 4 consumed: item-8
# Producer-2        INFO     Produced: item-7
# Consumer-1        INFO     Consumer 1 consumed: item-7
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Producer-0        INFO     Produced: item-9
# Consumer-0        INFO     Consumer 0 consumed: item-9
# Producer-1        INFO     Produced: item-9
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Consumer-1        INFO     Consumer 1 consumed: item-9
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Producer-2        INFO     Produced: item-8
# Consumer-3        INFO     Consumer 3 consumed: item-8
# Producer-0        INFO     Produced: item-10
# Consumer-1        INFO     Consumer 1 consumed: item-10
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Producer-2        INFO     Produced: item-9
# Consumer-1        INFO     Consumer 1 consumed: item-9
# Producer-1        INFO     Produced: item-10
# Consumer-0        INFO     Consumer 0 consumed: item-10
# Consumer-2        INFO     Consumer 2: Timeout waiting for items.
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Producer-0        INFO     Produced: item-11
# Consumer-1        INFO     Consumer 1 consumed: item-11
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Producer-2        INFO     Produced: item-10
# Consumer-2        INFO     Consumer 2 consumed: item-10
# Consumer-4        INFO     Consumer 4: Timeout waiting for items.
# Producer-1        INFO     Produced: item-11
# Consumer-1        INFO     Consumer 1 consumed: item-11
# Producer-0        INFO     Produced: item-12
# Consumer-3        INFO     Consumer 3 consumed: item-12
# Producer-2        INFO     Produced: item-11
# Consumer-2        INFO     Consumer 2 consumed: item-11
# Consumer-0        INFO     Consumer 0: Timeout waiting for items.
# Producer-1        INFO     Produced: item-12
# Consumer-4        INFO     Consumer 4 consumed: item-12
# Consumer-3        INFO     Consumer 3: Timeout waiting for items.
# Timer             INFO     Timer finished, requesting all threads to stop...
# Consumer-1        INFO     Consumer 1 stopping...
# Producer-0        INFO     Producer stopping...
# Consumer-2        INFO     Consumer 2 stopping...
# Consumer-0        INFO     Consumer 0 stopping...
# Producer-2        INFO     Producer stopping...
# Consumer-4        INFO     Consumer 4 stopping...
# Consumer-3        INFO     Consumer 3 stopping...
# Producer-1        INFO     Producer stopping...
# MainThread        INFO     All threads terminated, program finished.

# %% [markdown]
# # 2.B

# %%
BUFFER_SIZE = 30
PRODUCER_SLEEP_MIN = 0.1
PRODUCER_SLEEP_MAX = 0.3
CONSUMER_SLEEP_MIN = 3.0
CONSUMER_SLEEP_MAX = 4.0
RUN_DURATION = 20
NUM_CONSUMERS = 5
NUM_PRODUCERS = 3

buffer = []
buffer_lock = threading.Lock()
empty_slots = threading.Semaphore(BUFFER_SIZE)
filled_slots = threading.Semaphore(0)

stop_threads = False

def main():
    producers = []
    for i in range(NUM_PRODUCERS):
        t = threading.Thread(target=producer, args=(PRODUCER_SLEEP_MIN, PRODUCER_SLEEP_MAX), name=f"Producer-{i}")
        t.start()
        producers.append(t)
    consumers = []
    for i in range(NUM_CONSUMERS):
        t = threading.Thread(target=consumer, args=(i, CONSUMER_SLEEP_MIN, CONSUMER_SLEEP_MAX), name=f"Consumer-{i}")
        t.start()
        consumers.append(t)
    t_timer = threading.Thread(target=timer_thread, args=(RUN_DURATION,), name="Timer")
    t_timer.start()
    t_timer.join()
    for t in producers:
        t.join()
    for t in consumers:
        t.join()
    logging.info("All threads terminated, program finished.")

if __name__ == "__main__":
    main()
# Out:
# Producer-2        INFO     Produced: item-0
# Producer-0        INFO     Produced: item-0
# Producer-1        INFO     Produced: item-0
# Producer-0        INFO     Produced: item-1
# Producer-1        INFO     Produced: item-1
# Producer-0        INFO     Produced: item-2
# Producer-2        INFO     Produced: item-1
# Producer-1        INFO     Produced: item-2
# Producer-0        INFO     Produced: item-3
# Producer-2        INFO     Produced: item-2
# Producer-0        INFO     Produced: item-4
# Producer-2        INFO     Produced: item-3
# Producer-1        INFO     Produced: item-3
# Producer-0        INFO     Produced: item-5
# Producer-2        INFO     Produced: item-4
# Producer-1        INFO     Produced: item-4
# Producer-1        INFO     Produced: item-5
# Producer-2        INFO     Produced: item-5
# Producer-0        INFO     Produced: item-6
# Producer-2        INFO     Produced: item-6
# Producer-2        INFO     Produced: item-7
# Producer-1        INFO     Produced: item-6
# Producer-0        INFO     Produced: item-7
# Producer-1        INFO     Produced: item-7
# Producer-0        INFO     Produced: item-8
# Producer-2        INFO     Produced: item-8
# Producer-1        INFO     Produced: item-8
# Producer-2        INFO     Produced: item-9
# Producer-0        INFO     Produced: item-9
# Producer-2        INFO     Produced: item-10
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Producer-2        INFO     Producer: Timeout waiting for empty slot.
# Consumer-4        INFO     Consumer 4 consumed: item-0
# Producer-1        INFO     Produced: item-9
# Consumer-2        INFO     Consumer 2 consumed: item-0
# Producer-0        INFO     Produced: item-10
# Consumer-0        INFO     Consumer 0 consumed: item-0
# Producer-2        INFO     Produced: item-11
# Consumer-1        INFO     Consumer 1 consumed: item-1
# Consumer-3        INFO     Consumer 3 consumed: item-1
# Producer-0        INFO     Produced: item-11
# Producer-1        INFO     Produced: item-10
# Producer-2        INFO     Producer: Timeout waiting for empty slot.
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Producer-2        INFO     Producer: Timeout waiting for empty slot.
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Consumer-1        INFO     Consumer 1 consumed: item-2
# Producer-2        INFO     Produced: item-12
# Consumer-3        INFO     Consumer 3 consumed: item-1
# Producer-0        INFO     Produced: item-12
# Consumer-4        INFO     Consumer 4 consumed: item-2
# Producer-1        INFO     Produced: item-11
# Consumer-2        INFO     Consumer 2 consumed: item-3
# Producer-2        INFO     Produced: item-13
# Consumer-0        INFO     Consumer 0 consumed: item-2
# Producer-1        INFO     Produced: item-12
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Producer-2        INFO     Producer: Timeout waiting for empty slot.
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Producer-2        INFO     Producer: Timeout waiting for empty slot.
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Consumer-4        INFO     Consumer 4 consumed: item-4
# Producer-0        INFO     Produced: item-13
# Consumer-1        INFO     Consumer 1 consumed: item-3
# Producer-2        INFO     Produced: item-14
# Consumer-3        INFO     Consumer 3 consumed: item-3
# Producer-1        INFO     Produced: item-13
# Consumer-0        INFO     Consumer 0 consumed: item-5
# Producer-0        INFO     Produced: item-14
# Consumer-2        INFO     Consumer 2 consumed: item-4
# Producer-2        INFO     Produced: item-15
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Producer-2        INFO     Producer: Timeout waiting for empty slot.
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Consumer-4        INFO     Consumer 4 consumed: item-4
# Producer-2        INFO     Produced: item-16
# Consumer-1        INFO     Consumer 1 consumed: item-5
# Producer-1        INFO     Produced: item-14
# Consumer-0        INFO     Consumer 0 consumed: item-5
# Producer-0        INFO     Produced: item-15
# Producer-2        INFO     Producer: Timeout waiting for empty slot.
# Consumer-3        INFO     Consumer 3 consumed: item-6
# Producer-0        INFO     Produced: item-16
# Consumer-2        INFO     Consumer 2 consumed: item-6
# Producer-1        INFO     Produced: item-15
# Producer-2        INFO     Producer: Timeout waiting for empty slot.
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Consumer-4        INFO     Consumer 4 consumed: item-7
# Producer-2        INFO     Produced: item-17
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Consumer-1        INFO     Consumer 1 consumed: item-6
# Producer-2        INFO     Produced: item-18
# Consumer-0        INFO     Consumer 0 consumed: item-7
# Producer-0        INFO     Produced: item-17
# Consumer-3        INFO     Consumer 3 consumed: item-7
# Producer-1        INFO     Produced: item-16
# Consumer-2        INFO     Consumer 2 consumed: item-8
# Producer-2        INFO     Produced: item-19
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Producer-2        INFO     Producer: Timeout waiting for empty slot.
# Producer-0        INFO     Producer: Timeout waiting for empty slot.
# Timer             INFO     Timer finished, requesting all threads to stop...
# Producer-0        INFO     Producer stopping...
# Producer-1        INFO     Producer: Timeout waiting for empty slot.
# Producer-1        INFO     Producer stopping...
# Consumer-4        INFO     Consumer 4 stopping...
# Consumer-0        INFO     Consumer 0 stopping...
# Producer-2        INFO     Producer: Timeout waiting for empty slot.
# Producer-2        INFO     Producer stopping...
# Consumer-1        INFO     Consumer 1 stopping...
# Consumer-3        INFO     Consumer 3 stopping...
# Consumer-2        INFO     Consumer 2 stopping...
# MainThread        INFO     All threads terminated, program finished.

# %% [markdown]
# # 2.C

# %%
BUFFER_SIZE = 30
PRODUCER_SLEEP_MIN = 0.2
PRODUCER_SLEEP_MAX = 0.4
CONSUMER_SLEEP_MIN = 0.45
CONSUMER_SLEEP_MAX = 0.6
RUN_DURATION = 20
NUM_CONSUMERS = 5
NUM_PRODUCERS = 3

buffer = []
buffer_lock = threading.Lock()
empty_slots = threading.Semaphore(BUFFER_SIZE)
filled_slots = threading.Semaphore(0)

stop_threads = False

def main():
    producers = []
    for i in range(NUM_PRODUCERS):
        t = threading.Thread(target=producer, args=(PRODUCER_SLEEP_MIN, PRODUCER_SLEEP_MAX), name=f"Producer-{i}")
        t.start()
        producers.append(t)
    consumers = []
    for i in range(NUM_CONSUMERS):
        t = threading.Thread(target=consumer, args=(i, CONSUMER_SLEEP_MIN, CONSUMER_SLEEP_MAX), name=f"Consumer-{i}")
        t.start()
        consumers.append(t)
    t_timer = threading.Thread(target=timer_thread, args=(RUN_DURATION,), name="Timer")
    t_timer.start()
    t_timer.join()
    for t in producers:
        t.join()
    for t in consumers:
        t.join()
    logging.info("All threads terminated, program finished.")

if __name__ == "__main__":
    main()
# Out:
# Producer-1        INFO     Produced: item-0
# Producer-2        INFO     Produced: item-0
# Producer-0        INFO     Produced: item-0
# Consumer-4        INFO     Consumer 4 consumed: item-0
# Consumer-0        INFO     Consumer 0 consumed: item-0
# Producer-1        INFO     Produced: item-1
# Consumer-1        INFO     Consumer 1 consumed: item-0
# Consumer-3        INFO     Consumer 3 consumed: item-1
# Producer-2        INFO     Produced: item-1
# Consumer-2        INFO     Consumer 2 consumed: item-1
# Producer-0        INFO     Produced: item-1
# Producer-1        INFO     Produced: item-2
# Producer-2        INFO     Produced: item-2
# Consumer-4        INFO     Consumer 4 consumed: item-1
# Consumer-0        INFO     Consumer 0 consumed: item-2
# Consumer-3        INFO     Consumer 3 consumed: item-2
# Producer-0        INFO     Produced: item-2
# Consumer-1        INFO     Consumer 1 consumed: item-2
# Producer-1        INFO     Produced: item-3
# Producer-2        INFO     Produced: item-3
# Consumer-2        INFO     Consumer 2 consumed: item-3
# Producer-0        INFO     Produced: item-3
# Producer-1        INFO     Produced: item-4
# Consumer-4        INFO     Consumer 4 consumed: item-3
# Consumer-3        INFO     Consumer 3 consumed: item-3
# Consumer-0        INFO     Consumer 0 consumed: item-4
# Producer-0        INFO     Produced: item-4
# Producer-2        INFO     Produced: item-4
# Consumer-1        INFO     Consumer 1 consumed: item-4
# Consumer-2        INFO     Consumer 2 consumed: item-4
# Producer-1        INFO     Produced: item-5
# Producer-2        INFO     Produced: item-5
# Producer-0        INFO     Produced: item-5
# Consumer-4        INFO     Consumer 4 consumed: item-5
# Consumer-0        INFO     Consumer 0 consumed: item-5
# Consumer-3        INFO     Consumer 3 consumed: item-5
# Producer-2        INFO     Produced: item-6
# Consumer-1        INFO     Consumer 1 consumed: item-6
# Producer-1        INFO     Produced: item-6
# Producer-0        INFO     Produced: item-6
# Consumer-2        INFO     Consumer 2 consumed: item-6
# Producer-2        INFO     Produced: item-7
# Producer-1        INFO     Produced: item-7
# Consumer-4        INFO     Consumer 4 consumed: item-6
# Consumer-1        INFO     Consumer 1 consumed: item-7
# Producer-0        INFO     Produced: item-7
# Consumer-0        INFO     Consumer 0 consumed: item-7
# Producer-2        INFO     Produced: item-8
# Producer-1        INFO     Produced: item-8
# Consumer-3        INFO     Consumer 3 consumed: item-7
# Producer-2        INFO     Produced: item-9
# Consumer-2        INFO     Consumer 2 consumed: item-8
# Producer-0        INFO     Produced: item-8
# Consumer-4        INFO     Consumer 4 consumed: item-8
# Producer-1        INFO     Produced: item-9
# Consumer-1        INFO     Consumer 1 consumed: item-9
# Consumer-0        INFO     Consumer 0 consumed: item-8
# Consumer-3        INFO     Consumer 3 consumed: item-9
# Producer-0        INFO     Produced: item-9
# Producer-2        INFO     Produced: item-10
# Producer-1        INFO     Produced: item-10
# Consumer-2        INFO     Consumer 2 consumed: item-9
# Producer-2        INFO     Produced: item-11
# Consumer-1        INFO     Consumer 1 consumed: item-10
# Consumer-0        INFO     Consumer 0 consumed: item-10
# Producer-0        INFO     Produced: item-10
# Consumer-4        INFO     Consumer 4 consumed: item-11
# Producer-1        INFO     Produced: item-11
# Consumer-3        INFO     Consumer 3 consumed: item-10
# Producer-2        INFO     Produced: item-12
# Producer-0        INFO     Produced: item-11
# Consumer-2        INFO     Consumer 2 consumed: item-11
# Producer-1        INFO     Produced: item-12
# Consumer-1        INFO     Consumer 1 consumed: item-12
# Consumer-0        INFO     Consumer 0 consumed: item-11
# Producer-0        INFO     Produced: item-12
# Consumer-4        INFO     Consumer 4 consumed: item-12
# Producer-2        INFO     Produced: item-13
# Consumer-3        INFO     Consumer 3 consumed: item-12
# Producer-1        INFO     Produced: item-13
# Producer-0        INFO     Produced: item-13
# Consumer-2        INFO     Consumer 2 consumed: item-13
# Producer-2        INFO     Produced: item-14
# Producer-1        INFO     Produced: item-14
# Consumer-1        INFO     Consumer 1 consumed: item-13
# Producer-0        INFO     Produced: item-14
# Consumer-0        INFO     Consumer 0 consumed: item-13
# Consumer-4        INFO     Consumer 4 consumed: item-14
# Producer-1        INFO     Produced: item-15
# Consumer-3        INFO     Consumer 3 consumed: item-14
# Producer-2        INFO     Produced: item-15
# Producer-0        INFO     Produced: item-15
# Consumer-2        INFO     Consumer 2 consumed: item-14
# Producer-1        INFO     Produced: item-16
# Producer-2        INFO     Produced: item-16
# Consumer-1        INFO     Consumer 1 consumed: item-15
# Producer-0        INFO     Produced: item-16
# Consumer-0        INFO     Consumer 0 consumed: item-15
# Consumer-4        INFO     Consumer 4 consumed: item-15
# Producer-2        INFO     Produced: item-17
# Producer-1        INFO     Produced: item-17
# Producer-0        INFO     Produced: item-17
# Consumer-3        INFO     Consumer 3 consumed: item-16
# Consumer-2        INFO     Consumer 2 consumed: item-16
# Producer-2        INFO     Produced: item-18
# Consumer-1        INFO     Consumer 1 consumed: item-16
# Producer-0        INFO     Produced: item-18
# Producer-1        INFO     Produced: item-18
# Consumer-4        INFO     Consumer 4 consumed: item-17
# Consumer-0        INFO     Consumer 0 consumed: item-17
# Consumer-3        INFO     Consumer 3 consumed: item-17
# Producer-2        INFO     Produced: item-19
# Consumer-2        INFO     Consumer 2 consumed: item-18
# Producer-0        INFO     Produced: item-19
# Producer-1        INFO     Produced: item-19
# Producer-2        INFO     Produced: item-20
# Consumer-1        INFO     Consumer 1 consumed: item-18
# Consumer-0        INFO     Consumer 0 consumed: item-18
# Producer-0        INFO     Produced: item-20
# Producer-1        INFO     Produced: item-20
# Consumer-4        INFO     Consumer 4 consumed: item-19
# Consumer-3        INFO     Consumer 3 consumed: item-19
# Producer-2        INFO     Produced: item-21
# Producer-1        INFO     Produced: item-21
# Producer-0        INFO     Produced: item-21
# Consumer-2        INFO     Consumer 2 consumed: item-19
# Consumer-1        INFO     Consumer 1 consumed: item-20
# Producer-2        INFO     Produced: item-22
# Producer-1        INFO     Produced: item-22
# Consumer-4        INFO     Consumer 4 consumed: item-20
# Consumer-3        INFO     Consumer 3 consumed: item-20
# Consumer-0        INFO     Consumer 0 consumed: item-21
# Producer-0        INFO     Produced: item-22
# Consumer-2        INFO     Consumer 2 consumed: item-21
# Consumer-1        INFO     Consumer 1 consumed: item-21
# Producer-0        INFO     Produced: item-23
# Producer-2        INFO     Produced: item-23
# Producer-1        INFO     Produced: item-23
# Consumer-3        INFO     Consumer 3 consumed: item-22
# Consumer-0        INFO     Consumer 0 consumed: item-22
# Consumer-4        INFO     Consumer 4 consumed: item-22
# Producer-0        INFO     Produced: item-24
# Producer-2        INFO     Produced: item-24
# Producer-1        INFO     Produced: item-24
# Consumer-2        INFO     Consumer 2 consumed: item-23
# Consumer-1        INFO     Consumer 1 consumed: item-23
# Producer-2        INFO     Produced: item-25
# Producer-1        INFO     Produced: item-25
# Consumer-3        INFO     Consumer 3 consumed: item-23
# Producer-0        INFO     Produced: item-25
# Consumer-0        INFO     Consumer 0 consumed: item-24
# Consumer-4        INFO     Consumer 4 consumed: item-24
# Producer-0        INFO     Produced: item-26
# Consumer-2        INFO     Consumer 2 consumed: item-24
# Producer-2        INFO     Produced: item-26
# Producer-1        INFO     Produced: item-26
# Consumer-1        INFO     Consumer 1 consumed: item-25
# Producer-0        INFO     Produced: item-27
# Producer-1        INFO     Produced: item-27
# Consumer-3        INFO     Consumer 3 consumed: item-25
# Producer-2        INFO     Produced: item-27
# Consumer-0        INFO     Consumer 0 consumed: item-25
# Consumer-4        INFO     Consumer 4 consumed: item-26
# Producer-0        INFO     Produced: item-28
# Consumer-2        INFO     Consumer 2 consumed: item-26
# Producer-2        INFO     Produced: item-28
# Producer-1        INFO     Produced: item-28
# Consumer-1        INFO     Consumer 1 consumed: item-26
# Producer-2        INFO     Produced: item-29
# Producer-0        INFO     Produced: item-29
# Consumer-3        INFO     Consumer 3 consumed: item-27
# Producer-1        INFO     Produced: item-29
# Consumer-0        INFO     Consumer 0 consumed: item-27
# Consumer-4        INFO     Consumer 4 consumed: item-27
# Consumer-2        INFO     Consumer 2 consumed: item-28
# Producer-2        INFO     Produced: item-30
# Producer-0        INFO     Produced: item-30
# Consumer-1        INFO     Consumer 1 consumed: item-28
# Producer-1        INFO     Produced: item-30
# Producer-0        INFO     Produced: item-31
# Consumer-3        INFO     Consumer 3 consumed: item-28
# Consumer-0        INFO     Consumer 0 consumed: item-29
# Consumer-4        INFO     Consumer 4 consumed: item-29
# Producer-1        INFO     Produced: item-31
# Producer-2        INFO     Produced: item-31
# Consumer-2        INFO     Consumer 2 consumed: item-29
# Producer-0        INFO     Produced: item-32
# Producer-1        INFO     Produced: item-32
# Consumer-1        INFO     Consumer 1 consumed: item-30
# Producer-2        INFO     Produced: item-32
# Producer-0        INFO     Produced: item-33
# Consumer-0        INFO     Consumer 0 consumed: item-30
# Consumer-3        INFO     Consumer 3 consumed: item-30
# Producer-1        INFO     Produced: item-33
# Consumer-4        INFO     Consumer 4 consumed: item-31
# Producer-2        INFO     Produced: item-33
# Consumer-2        INFO     Consumer 2 consumed: item-31
# Producer-0        INFO     Produced: item-34
# Consumer-1        INFO     Consumer 1 consumed: item-31
# Producer-1        INFO     Produced: item-34
# Consumer-3        INFO     Consumer 3 consumed: item-32
# Consumer-0        INFO     Consumer 0 consumed: item-32
# Producer-0        INFO     Produced: item-35
# Consumer-4        INFO     Consumer 4 consumed: item-32
# Producer-2        INFO     Produced: item-34
# Producer-1        INFO     Produced: item-35
# Consumer-2        INFO     Consumer 2 consumed: item-33
# Consumer-1        INFO     Consumer 1 consumed: item-33
# Producer-0        INFO     Produced: item-36
# Producer-2        INFO     Produced: item-35
# Consumer-3        INFO     Consumer 3 consumed: item-33
# Producer-1        INFO     Produced: item-36
# Producer-0        INFO     Produced: item-37
# Consumer-4        INFO     Consumer 4 consumed: item-34
# Consumer-0        INFO     Consumer 0 consumed: item-34
# Producer-2        INFO     Produced: item-36
# Consumer-2        INFO     Consumer 2 consumed: item-35
# Producer-0        INFO     Produced: item-38
# Producer-1        INFO     Produced: item-37
# Consumer-1        INFO     Consumer 1 consumed: item-34
# Consumer-3        INFO     Consumer 3 consumed: item-35
# Producer-2        INFO     Produced: item-37
# Consumer-4        INFO     Consumer 4 consumed: item-36
# Consumer-0        INFO     Consumer 0 consumed: item-35
# Producer-0        INFO     Produced: item-39
# Consumer-2        INFO     Consumer 2 consumed: item-36
# Producer-2        INFO     Produced: item-38
# Producer-1        INFO     Produced: item-38
# Producer-0        INFO     Produced: item-40
# Consumer-1        INFO     Consumer 1 consumed: item-37
# Producer-2        INFO     Produced: item-39
# Consumer-3        INFO     Consumer 3 consumed: item-36
# Producer-1        INFO     Produced: item-39
# Consumer-4        INFO     Consumer 4 consumed: item-38
# Consumer-2        INFO     Consumer 2 consumed: item-37
# Consumer-0        INFO     Consumer 0 consumed: item-37
# Producer-2        INFO     Produced: item-40
# Producer-0        INFO     Produced: item-41
# Producer-1        INFO     Produced: item-40
# Producer-2        INFO     Produced: item-41
# Consumer-1        INFO     Consumer 1 consumed: item-39
# Producer-0        INFO     Produced: item-42
# Consumer-3        INFO     Consumer 3 consumed: item-38
# Consumer-4        INFO     Consumer 4 consumed: item-38
# Consumer-0        INFO     Consumer 0 consumed: item-40
# Producer-1        INFO     Produced: item-41
# Consumer-2        INFO     Consumer 2 consumed: item-39
# Producer-2        INFO     Produced: item-42
# Producer-1        INFO     Produced: item-42
# Producer-0        INFO     Produced: item-43
# Consumer-3        INFO     Consumer 3 consumed: item-39
# Consumer-1        INFO     Consumer 1 consumed: item-40
# Producer-2        INFO     Produced: item-43
# Consumer-4        INFO     Consumer 4 consumed: item-41
# Consumer-0        INFO     Consumer 0 consumed: item-40
# Producer-1        INFO     Produced: item-43
# Producer-0        INFO     Produced: item-44
# Consumer-2        INFO     Consumer 2 consumed: item-41
# Producer-2        INFO     Produced: item-44
# Producer-1        INFO     Produced: item-44
# Consumer-3        INFO     Consumer 3 consumed: item-42
# Producer-2        INFO     Produced: item-45
# Consumer-1        INFO     Consumer 1 consumed: item-41
# Producer-0        INFO     Produced: item-45
# Consumer-4        INFO     Consumer 4 consumed: item-42
# Producer-1        INFO     Produced: item-45
# Consumer-0        INFO     Consumer 0 consumed: item-42
# Consumer-2        INFO     Consumer 2 consumed: item-43
# Producer-2        INFO     Produced: item-46
# Producer-0        INFO     Produced: item-46
# Consumer-3        INFO     Consumer 3 consumed: item-43
# Producer-1        INFO     Produced: item-46
# Consumer-1        INFO     Consumer 1 consumed: item-43
# Consumer-4        INFO     Consumer 4 consumed: item-44
# Producer-2        INFO     Produced: item-47
# Producer-1        INFO     Produced: item-47
# Consumer-0        INFO     Consumer 0 consumed: item-44
# Producer-0        INFO     Produced: item-47
# Consumer-2        INFO     Consumer 2 consumed: item-44
# Producer-2        INFO     Produced: item-48
# Producer-0        INFO     Produced: item-48
# Consumer-3        INFO     Consumer 3 consumed: item-45
# Consumer-1        INFO     Consumer 1 consumed: item-45
# Producer-1        INFO     Produced: item-48
# Consumer-4        INFO     Consumer 4 consumed: item-45
# Producer-2        INFO     Produced: item-49
# Consumer-0        INFO     Consumer 0 consumed: item-46
# Producer-0        INFO     Produced: item-49
# Producer-1        INFO     Produced: item-49
# Consumer-2        INFO     Consumer 2 consumed: item-46
# Consumer-3        INFO     Consumer 3 consumed: item-46
# Producer-0        INFO     Produced: item-50
# Producer-2        INFO     Produced: item-50
# Consumer-1        INFO     Consumer 1 consumed: item-47
# Producer-1        INFO     Produced: item-50
# Consumer-0        INFO     Consumer 0 consumed: item-47
# Consumer-4        INFO     Consumer 4 consumed: item-47
# Producer-0        INFO     Produced: item-51
# Producer-1        INFO     Produced: item-51
# Producer-2        INFO     Produced: item-51
# Consumer-2        INFO     Consumer 2 consumed: item-48
# Consumer-3        INFO     Consumer 3 consumed: item-48
# Consumer-1        INFO     Consumer 1 consumed: item-48
# Consumer-0        INFO     Consumer 0 consumed: item-49
# Producer-1        INFO     Produced: item-52
# Producer-0        INFO     Produced: item-52
# Producer-2        INFO     Produced: item-52
# Consumer-4        INFO     Consumer 4 consumed: item-49
# Producer-0        INFO     Produced: item-53
# Consumer-2        INFO     Consumer 2 consumed: item-49
# Producer-1        INFO     Produced: item-53
# Consumer-3        INFO     Consumer 3 consumed: item-50
# Producer-2        INFO     Produced: item-53
# Consumer-1        INFO     Consumer 1 consumed: item-50
# Producer-0        INFO     Produced: item-54
# Consumer-0        INFO     Consumer 0 consumed: item-50
# Consumer-4        INFO     Consumer 4 consumed: item-51
# Producer-1        INFO     Produced: item-54
# Producer-0        INFO     Produced: item-55
# Consumer-2        INFO     Consumer 2 consumed: item-51
# Producer-2        INFO     Produced: item-54
# Producer-1        INFO     Produced: item-55
# Consumer-3        INFO     Consumer 3 consumed: item-51
# Producer-0        INFO     Produced: item-56
# Consumer-1        INFO     Consumer 1 consumed: item-52
# Consumer-4        INFO     Consumer 4 consumed: item-52
# Consumer-0        INFO     Consumer 0 consumed: item-52
# Producer-2        INFO     Produced: item-55
# Producer-1        INFO     Produced: item-56
# Producer-0        INFO     Produced: item-57
# Consumer-2        INFO     Consumer 2 consumed: item-53
# Consumer-3        INFO     Consumer 3 consumed: item-53
# Producer-2        INFO     Produced: item-56
# Producer-1        INFO     Produced: item-57
# Consumer-1        INFO     Consumer 1 consumed: item-53
# Consumer-4        INFO     Consumer 4 consumed: item-54
# Consumer-0        INFO     Consumer 0 consumed: item-54
# Producer-0        INFO     Produced: item-58
# Producer-2        INFO     Produced: item-57
# Producer-1        INFO     Produced: item-58
# Consumer-2        INFO     Consumer 2 consumed: item-55
# Consumer-3        INFO     Consumer 3 consumed: item-54
# Producer-0        INFO     Produced: item-59
# Consumer-1        INFO     Consumer 1 consumed: item-55
# Producer-1        INFO     Produced: item-59
# Producer-2        INFO     Produced: item-58
# Consumer-4        INFO     Consumer 4 consumed: item-56
# Consumer-0        INFO     Consumer 0 consumed: item-55
# Producer-0        INFO     Produced: item-60
# Producer-1        INFO     Produced: item-60
# Producer-2        INFO     Produced: item-59
# Consumer-2        INFO     Consumer 2 consumed: item-56
# Consumer-3        INFO     Consumer 3 consumed: item-57
# Consumer-1        INFO     Consumer 1 consumed: item-56
# Producer-0        INFO     Produced: item-61
# Consumer-4        INFO     Consumer 4 consumed: item-57
# Producer-1        INFO     Produced: item-61
# Producer-2        INFO     Produced: item-60
# Consumer-0        INFO     Consumer 0 consumed: item-58
# Producer-0        INFO     Produced: item-62
# Producer-1        INFO     Produced: item-62
# Consumer-3        INFO     Consumer 3 consumed: item-57
# Consumer-2        INFO     Consumer 2 consumed: item-58
# Producer-2        INFO     Produced: item-61
# Consumer-1        INFO     Consumer 1 consumed: item-59
# Consumer-4        INFO     Consumer 4 consumed: item-59
# Producer-0        INFO     Produced: item-63
# Consumer-0        INFO     Consumer 0 consumed: item-58
# Producer-1        INFO     Produced: item-63
# Producer-2        INFO     Produced: item-62
# Consumer-3        INFO     Consumer 3 consumed: item-60
# Producer-1        INFO     Produced: item-64
# Consumer-2        INFO     Consumer 2 consumed: item-60
# Producer-0        INFO     Produced: item-64
# Consumer-1        INFO     Consumer 1 consumed: item-59
# Producer-2        INFO     Produced: item-63
# Consumer-0        INFO     Consumer 0 consumed: item-61
# Timer             INFO     Timer finished, requesting all threads to stop...
# Producer-1        INFO     Producer stopping...
# Consumer-4        INFO     Consumer 4 stopping...
# Producer-0        INFO     Producer stopping...
# Producer-2        INFO     Producer stopping...
# Consumer-2        INFO     Consumer 2 stopping...
# Consumer-3        INFO     Consumer 3 stopping...
# Consumer-1        INFO     Consumer 1 stopping...
# Consumer-0        INFO     Consumer 0 stopping...
# MainThread        INFO     All threads terminated, program finished.

# %% [markdown]
# # 2.A

# %%
import threading
import queue
import time
import random

BUFFER_SIZE = 30
q = queue.Queue(BUFFER_SIZE)
stop_threads = False

def producer(prod_id, first, last):
    item_id = 0
    while True:
        if stop_threads:
            print(f"Producer {prod_id} stopping...")
            break
        
        time.sleep(random.uniform(first, last))
        item = f"P{prod_id}-item-{item_id}"
        if not q.full():
            q.put(item, timeout=1)
            print(f"Producer {prod_id} produced: {item}")
            item_id += 1
        else:
            print(f"Producer {prod_id}: queue is full, waiting for 1 second")
            time.sleep(1)

def consumer(consumer_id, first, last):
    while True:
        if stop_threads:
            print(f"Consumer {consumer_id} stopping...")
            break
        
        time.sleep(random.uniform(first, last))
        if not q.empty():
            item = q.get(timeout=1)
            print(f"Consumer {consumer_id} consumed: {item}")
            q.task_done()
        else:
            print(f"Consumer {consumer_id}: queue is empty, waiting for 1 second")
            time.sleep(1)

def timer_thread(duration):
    time.sleep(duration)
    global stop_threads
    stop_threads = True
    print("Timer finished, requesting all threads to stop...")

if __name__ == "__main__":
    producers = []
    for i in range(3):
        t = threading.Thread(target=producer, args=(i, 1., 2.,))
        t.start()
        producers.append(t)
    
    consumers = []
    for i in range(5):
        t = threading.Thread(target=consumer, args=(i, 0.1, 0.5,))
        t.start()
        consumers.append(t)

    t_timer = threading.Thread(target=timer_thread, args=(20,))
    t_timer.start()

    for t in producers:
        t.join()
    for t in consumers:
        t.join()
    t_timer.join()

    print("All threads terminated, program finished.")
# Out:
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 0: queue is empty, waiting for 1 second
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 4: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Producer 2 produced: P2-item-0
# Consumer 1 consumed: P2-item-0
# Producer 1 produced: P1-item-0
# Consumer 4 consumed: P1-item-0
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Consumer 0: queue is empty, waiting for 1 second
# Consumer 1: queue is empty, waiting for 1 second
# Producer 0 produced: P0-item-0
# Consumer 4 consumed: P0-item-0
# Consumer 4: queue is empty, waiting for 1 second
# Producer 2 produced: P2-item-1
# Producer 0 produced: P0-item-1
# Consumer 2 consumed: P2-item-1
# Consumer 3 consumed: P0-item-1
# Consumer 0: queue is empty, waiting for 1 second
# Producer 1 produced: P1-item-1
# Consumer 2 consumed: P1-item-1
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Consumer 4: queue is empty, waiting for 1 second
# Producer 1 produced: P1-item-2
# Consumer 0 consumed: P1-item-2
# Consumer 1: queue is empty, waiting for 1 second
# Producer 2 produced: P2-item-2
# Consumer 0 consumed: P2-item-2
# Producer 0 produced: P0-item-2
# Consumer 3 consumed: P0-item-2
# Consumer 2: queue is empty, waiting for 1 second
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 0: queue is empty, waiting for 1 second
# Consumer 4: queue is empty, waiting for 1 second
# Producer 1 produced: P1-item-3
# Producer 2 produced: P2-item-3
# Producer 0 produced: P0-item-3
# Consumer 1 consumed: P1-item-3
# Consumer 2 consumed: P2-item-3
# Consumer 0 consumed: P0-item-3
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Consumer 0: queue is empty, waiting for 1 second
# Consumer 4: queue is empty, waiting for 1 second
# Producer 2 produced: P2-item-4
# Producer 0 produced: P0-item-4
# Producer 1 produced: P1-item-4
# Consumer 3 consumed: P2-item-4
# Consumer 1 consumed: P0-item-4
# Consumer 2 consumed: P1-item-4
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 0: queue is empty, waiting for 1 second
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 4: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Producer 2 produced: P2-item-5
# Producer 0 produced: P0-item-5
# Consumer 3 consumed: P2-item-5
# Consumer 0 consumed: P0-item-5
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 4: queue is empty, waiting for 1 second
# Producer 1 produced: P1-item-5
# Consumer 0 consumed: P1-item-5
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Consumer 0: queue is empty, waiting for 1 second
# Producer 2 produced: P2-item-6
# Producer 0 produced: P0-item-6
# Consumer 3 consumed: P2-item-6
# Consumer 4 consumed: P0-item-6Consumer 1: queue is empty, waiting for 1 second
#
# Consumer 2: queue is empty, waiting for 1 second
# Consumer 0: queue is empty, waiting for 1 second
# Consumer 3: queue is empty, waiting for 1 second
# Producer 2 produced: P2-item-7
# Producer 1 produced: P1-item-6
# Consumer 4 consumed: P2-item-7
# Consumer 4 consumed: P1-item-6
# Consumer 4: queue is empty, waiting for 1 second
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Producer 0 produced: P0-item-7
# Consumer 0 consumed: P0-item-7
# Producer 2 produced: P2-item-8
# Consumer 3 consumed: P2-item-8
# Consumer 0: queue is empty, waiting for 1 second
# Producer 1 produced: P1-item-7
# Consumer 3 consumed: P1-item-7
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 4: queue is empty, waiting for 1 second
# Consumer 1: queue is empty, waiting for 1 second
# Producer 2 produced: P2-item-9
# Consumer 2 consumed: P2-item-9
# Consumer 0: queue is empty, waiting for 1 second
# Producer 1 produced: P1-item-8
# Producer 0 produced: P0-item-8
# Consumer 2 consumed: P1-item-8
# Consumer 4 consumed: P0-item-8
# Consumer 2: queue is empty, waiting for 1 second
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 4: queue is empty, waiting for 1 second
# Producer 1 produced: P1-item-9
# Consumer 0 consumed: P1-item-9
# Producer 0 produced: P0-item-9
# Producer 2 produced: P2-item-10
# Consumer 0 consumed: P0-item-9
# Consumer 1 consumed: P2-item-10
# Consumer 0: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 4: queue is empty, waiting for 1 second
# Producer 1 produced: P1-item-10
# Consumer 2 consumed: P1-item-10
# Consumer 3: queue is empty, waiting for 1 second
# Consumer 0: queue is empty, waiting for 1 second
# Producer 0 produced: P0-item-10
# Producer 2 produced: P2-item-11
# Consumer 2 consumed: P0-item-10
# Consumer 1 consumed: P2-item-11
# Consumer 4: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 3: queue is empty, waiting for 1 second
# Producer 0 produced: P0-item-11
# Producer 1 produced: P1-item-11
# Consumer 0 consumed: P0-item-11
# Producer 2 produced: P2-item-12
# Consumer 0 consumed: P1-item-11
# Consumer 4 consumed: P2-item-12
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 0: queue is empty, waiting for 1 second
# Consumer 4: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Producer 0 produced: P0-item-12
# Consumer 3 consumed: P0-item-12
# Consumer 3: queue is empty, waiting for 1 second
# Producer 2 produced: P2-item-13
# Consumer 1 consumed: P2-item-13
# Timer finished, requesting all threads to stop...
# Producer 1 produced: P1-item-12
# Producer 1 stopping...
# Consumer 4 consumed: P1-item-12
# Consumer 4 stopping...
# Consumer 0: queue is empty, waiting for 1 second
# Consumer 1: queue is empty, waiting for 1 second
# Consumer 2: queue is empty, waiting for 1 second
# Producer 0 produced: P0-item-13
# Producer 0 stopping...
# Consumer 3 stopping...
# Consumer 0 stopping...
# Consumer 1 stopping...
# Consumer 2 stopping...
# Producer 2 produced: P2-item-14
# Producer 2 stopping...
# All threads terminated, program finished.

# %% [markdown]
# ### 2. B

# %%
q = queue.Queue(BUFFER_SIZE)
stop_threads = False
if __name__ == "__main__":
    producers = []
    for i in range(3):
        t = threading.Thread(target=producer, args=(i, 0.1, 0.3,))
        t.start()
        producers.append(t)
    
    consumers = []
    for i in range(5):
        t = threading.Thread(target=consumer, args=(i, 3.0, 4.0,))
        t.start()
        consumers.append(t)

    t_timer = threading.Thread(target=timer_thread, args=(20,))
    t_timer.start()

    for t in producers:
        t.join()
    for t in consumers:
        t.join()
    t_timer.join()

    print("All threads terminated, program finished.")
# Out:
# Producer 0 produced: P0-item-0
# Producer 2 produced: P2-item-0
# Producer 1 produced: P1-item-0
# Producer 2 produced: P2-item-1
# Producer 0 produced: P0-item-1
# Producer 1 produced: P1-item-1
# Producer 2 produced: P2-item-2
# Producer 0 produced: P0-item-2
# Producer 1 produced: P1-item-2
# Producer 2 produced: P2-item-3
# Producer 0 produced: P0-item-3
# Producer 1 produced: P1-item-3
# Producer 0 produced: P0-item-4
# Producer 2 produced: P2-item-4
# Producer 1 produced: P1-item-4
# Producer 0 produced: P0-item-5
# Producer 2 produced: P2-item-5
# Producer 0 produced: P0-item-6
# Producer 1 produced: P1-item-5
# Producer 2 produced: P2-item-6
# Producer 1 produced: P1-item-6
# Producer 0 produced: P0-item-7
# Producer 2 produced: P2-item-7
# Producer 1 produced: P1-item-7
# Producer 1 produced: P1-item-8Producer 0 produced: P0-item-8
#
# Producer 2 produced: P2-item-8
# Producer 2 produced: P2-item-9
# Producer 0 produced: P0-item-9
# Producer 1 produced: P1-item-9
# Producer 1: queue is full, waiting for 1 second
# Producer 2: queue is full, waiting for 1 second
# Producer 0: queue is full, waiting for 1 second
# Consumer 1 consumed: P0-item-0
# Consumer 2 consumed: P2-item-0
# Consumer 4 consumed: P1-item-0
# Consumer 3 consumed: P2-item-1
# Producer 2 produced: P2-item-10
# Producer 1 produced: P1-item-10
# Producer 2 produced: P2-item-11
# Producer 1 produced: P1-item-11
# Producer 0: queue is full, waiting for 1 second
# Consumer 0 consumed: P0-item-1
# Producer 1 produced: P1-item-12
# Producer 2: queue is full, waiting for 1 second
# Producer 1: queue is full, waiting for 1 second
# Producer 0: queue is full, waiting for 1 second
# Producer 2: queue is full, waiting for 1 second
# Producer 1: queue is full, waiting for 1 second
# Producer 0: queue is full, waiting for 1 second
# Producer 2: queue is full, waiting for 1 second
# Producer 1: queue is full, waiting for 1 second
# Consumer 3 consumed: P1-item-1
# Consumer 1 consumed: P2-item-2
# Consumer 2 consumed: P0-item-2
# Consumer 4 consumed: P1-item-2
# Producer 0 produced: P0-item-10
# Producer 0 produced: P0-item-11
# Producer 0 produced: P0-item-12
# Consumer 0 consumed: P2-item-3
# Producer 1 produced: P1-item-13
# Producer 2 produced: P2-item-12
# Producer 0: queue is full, waiting for 1 second
# Producer 2: queue is full, waiting for 1 secondProducer 1: queue is full, waiting for 1 second
#
# Producer 0: queue is full, waiting for 1 second
# Producer 1: queue is full, waiting for 1 secondProducer 2: queue is full, waiting for 1 second
#
# Consumer 3 consumed: P0-item-3
# Consumer 1 consumed: P1-item-3
# Consumer 4 consumed: P0-item-4
# Consumer 2 consumed: P2-item-4
# Producer 0 produced: P0-item-13
# Producer 0 produced: P0-item-14
# Producer 1 produced: P1-item-14
# Producer 0 produced: P0-item-15
# Producer 2: queue is full, waiting for 1 second
# Producer 1: queue is full, waiting for 1 second
# Producer 0: queue is full, waiting for 1 second
# Consumer 0 consumed: P1-item-4
# Producer 2 produced: P2-item-13
# Producer 2: queue is full, waiting for 1 second
# Producer 1: queue is full, waiting for 1 second
# Producer 0: queue is full, waiting for 1 second
# Producer 2: queue is full, waiting for 1 second
# Producer 0: queue is full, waiting for 1 second
# Producer 1: queue is full, waiting for 1 second
# Consumer 2 consumed: P0-item-5
# Consumer 3 consumed: P2-item-5
# Consumer 4 consumed: P0-item-6
# Consumer 1 consumed: P1-item-5
# Producer 2 produced: P2-item-14
# Producer 0 produced: P0-item-16
# Producer 2 produced: P2-item-15
# Producer 0 produced: P0-item-17
# Producer 1: queue is full, waiting for 1 second
# Producer 2: queue is full, waiting for 1 second
# Producer 0: queue is full, waiting for 1 second
# Consumer 0 consumed: P2-item-6
# Producer 1 produced: P1-item-15
# Producer 2: queue is full, waiting for 1 second
# Producer 0: queue is full, waiting for 1 second
# Producer 1: queue is full, waiting for 1 second
# Consumer 3 consumed: P1-item-6
# Consumer 2 consumed: P0-item-7
# Consumer 4 consumed: P2-item-7
# Producer 2 produced: P2-item-16
# Producer 1 produced: P1-item-16
# Producer 0 produced: P0-item-18
# Producer 0: queue is full, waiting for 1 second
# Consumer 1 consumed: P1-item-7
# Producer 2 produced: P2-item-17
# Producer 1: queue is full, waiting for 1 second
# Producer 2: queue is full, waiting for 1 second
# Consumer 0 consumed: P1-item-8
# Producer 0 produced: P0-item-19
# Producer 1: queue is full, waiting for 1 second
# Producer 2: queue is full, waiting for 1 second
# Producer 0: queue is full, waiting for 1 second
# Producer 2: queue is full, waiting for 1 second
# Producer 1: queue is full, waiting for 1 second
# Producer 0: queue is full, waiting for 1 second
# Timer finished, requesting all threads to stop...
# Consumer 3 consumed: P0-item-8
# Consumer 3 stopping...
# Consumer 4 consumed: P2-item-8
# Consumer 4 stopping...
# Producer 2 stopping...
# Producer 1 stopping...
# Producer 0 stopping...
# Consumer 2 consumed: P2-item-9
# Consumer 2 stopping...
# Consumer 0 consumed: P0-item-9
# Consumer 0 stopping...
# Consumer 1 consumed: P1-item-9
# Consumer 1 stopping...
# All threads terminated, program finished.

# %%
q = queue.Queue(BUFFER_SIZE)
stop_threads = False
if __name__ == "__main__":
    producers = []
    for i in range(3):
        t = threading.Thread(target=producer, args=(i, .2, .4,))
        t.start()
        producers.append(t)
    
    consumers = []
    for i in range(5):
        t = threading.Thread(target=consumer, args=(i, 0.45, 0.6,))
        t.start()
        consumers.append(t)

    t_timer = threading.Thread(target=timer_thread, args=(20,))
    t_timer.start()

    for t in producers:
        t.join()
    for t in consumers:
        t.join()
    t_timer.join()

    print("All threads terminated, program finished.")
# Out:
# Producer 0 produced: P0-item-0
# Producer 1 produced: P1-item-0
# Producer 2 produced: P2-item-0
# Consumer 4 consumed: P0-item-0
# Consumer 0 consumed: P1-item-0
# Consumer 2 consumed: P2-item-0
# Producer 0 produced: P0-item-1
# Consumer 1 consumed: P0-item-1
# Producer 2 produced: P2-item-1
# Producer 1 produced: P1-item-1
# Consumer 3 consumed: P2-item-1
# Producer 1 produced: P1-item-2
# Producer 2 produced: P2-item-2
# Producer 0 produced: P0-item-2
# Consumer 2 consumed: P1-item-1
# Consumer 4 consumed: P1-item-2
# Consumer 0 consumed: P2-item-2
# Consumer 1 consumed: P0-item-2
# Consumer 3: queue is empty, waiting for 1 second
# Producer 1 produced: P1-item-3
# Producer 0 produced: P0-item-3
# Producer 2 produced: P2-item-3
# Producer 1 produced: P1-item-4
# Consumer 4 consumed: P1-item-3
# Producer 0 produced: P0-item-4
# Consumer 2 consumed: P0-item-3
# Consumer 0 consumed: P2-item-3
# Consumer 1 consumed: P1-item-4
# Producer 2 produced: P2-item-4
# Producer 1 produced: P1-item-5
# Producer 0 produced: P0-item-5
# Producer 1 produced: P1-item-6
# Producer 0 produced: P0-item-6
# Consumer 4 consumed: P0-item-4
# Consumer 2 consumed: P2-item-4
# Producer 2 produced: P2-item-5
# Consumer 0 consumed: P1-item-5
# Producer 1 produced: P1-item-7
# Consumer 1 consumed: P0-item-5
# Producer 2 produced: P2-item-6
# Producer 0 produced: P0-item-7
# Consumer 4 consumed: P1-item-6
# Producer 1 produced: P1-item-8
# Consumer 2 consumed: P0-item-6
# Producer 2 produced: P2-item-7
# Consumer 3 consumed: P2-item-5
# Consumer 1 consumed: P1-item-7
# Consumer 0 consumed: P2-item-6
# Producer 1 produced: P1-item-9
# Producer 0 produced: P0-item-8
# Producer 2 produced: P2-item-8
# Producer 1 produced: P1-item-10Consumer 4 consumed: P0-item-7
#
# Consumer 2 consumed: P1-item-8
# Producer 2 produced: P2-item-9
# Consumer 3 consumed: P2-item-7
# Producer 0 produced: P0-item-9
# Consumer 1 consumed: P1-item-9Consumer 0 consumed: P0-item-8
#
# Producer 1 produced: P1-item-11
# Consumer 4 consumed: P2-item-8
# Producer 2 produced: P2-item-10
# Producer 0 produced: P0-item-10
# Consumer 2 consumed: P1-item-10
# Producer 1 produced: P1-item-12
# Consumer 0 consumed: P2-item-9Consumer 1 consumed: P0-item-9
#
# Consumer 3 consumed: P1-item-11
# Producer 2 produced: P2-item-11
# Producer 0 produced: P0-item-11
# Consumer 4 consumed: P2-item-10
# Producer 1 produced: P1-item-13
# Producer 0 produced: P0-item-12
# Consumer 0 consumed: P0-item-10
# Consumer 2 consumed: P1-item-12
# Producer 2 produced: P2-item-12
# Consumer 3 consumed: P2-item-11
# Consumer 1 consumed: P0-item-11
# Producer 1 produced: P1-item-14
# Producer 0 produced: P0-item-13
# Producer 2 produced: P2-item-13
# Consumer 4 consumed: P1-item-13
# Consumer 0 consumed: P0-item-12
# Producer 1 produced: P1-item-15
# Consumer 2 consumed: P2-item-12
# Producer 2 produced: P2-item-14
# Producer 0 produced: P0-item-14
# Consumer 1 consumed: P1-item-14
# Consumer 3 consumed: P0-item-13
# Producer 0 produced: P0-item-15
# Consumer 4 consumed: P2-item-13
# Producer 1 produced: P1-item-16
# Consumer 0 consumed: P1-item-15
# Producer 2 produced: P2-item-15
# Producer 0 produced: P0-item-16
# Consumer 1 consumed: P2-item-14
# Consumer 2 consumed: P0-item-14
# Consumer 3 consumed: P0-item-15
# Producer 1 produced: P1-item-17
# Producer 0 produced: P0-item-17Consumer 4 consumed: P1-item-16
#
# Producer 2 produced: P2-item-16
# Producer 1 produced: P1-item-18
# Consumer 0 consumed: P2-item-15
# Consumer 2 consumed: P0-item-16
# Producer 2 produced: P2-item-17
# Consumer 1 consumed: P1-item-17
# Consumer 3 consumed: P0-item-17
# Producer 1 produced: P1-item-19
# Producer 0 produced: P0-item-18
# Consumer 4 consumed: P2-item-16
# Producer 2 produced: P2-item-18
# Consumer 0 consumed: P1-item-18
# Producer 0 produced: P0-item-19
# Producer 1 produced: P1-item-20
# Consumer 3 consumed: P2-item-17
# Consumer 1 consumed: P1-item-19
# Consumer 2 consumed: P0-item-18
# Producer 2 produced: P2-item-19
# Producer 1 produced: P1-item-21
# Consumer 4 consumed: P2-item-18
# Producer 0 produced: P0-item-20
# Producer 2 produced: P2-item-20
# Producer 1 produced: P1-item-22
# Consumer 0 consumed: P0-item-19
# Consumer 1 consumed: P1-item-20
# Consumer 3 consumed: P2-item-19
# Consumer 2 consumed: P1-item-21
# Producer 2 produced: P2-item-21
# Producer 0 produced: P0-item-21
# Producer 1 produced: P1-item-23
# Producer 2 produced: P2-item-22
# Consumer 4 consumed: P0-item-20
# Producer 1 produced: P1-item-24
# Producer 0 produced: P0-item-22
# Producer 2 produced: P2-item-23
# Consumer 0 consumed: P2-item-20
# Consumer 1 consumed: P1-item-22
# Consumer 2 consumed: P2-item-21
# Consumer 3 consumed: P0-item-21
# Producer 1 produced: P1-item-25
# Producer 2 produced: P2-item-24
# Producer 0 produced: P0-item-23
# Consumer 4 consumed: P1-item-23
# Consumer 0 consumed: P2-item-22
# Producer 2 produced: P2-item-25
# Producer 0 produced: P0-item-24
# Producer 1 produced: P1-item-26
# Consumer 2 consumed: P1-item-24
# Consumer 1 consumed: P0-item-22
# Consumer 3 consumed: P2-item-23
# Producer 2 produced: P2-item-26
# Consumer 4 consumed: P1-item-25
# Producer 1 produced: P1-item-27
# Producer 0 produced: P0-item-25
# Consumer 0 consumed: P2-item-24
# Consumer 1 consumed: P0-item-23
# Consumer 3 consumed: P2-item-25
# Producer 2 produced: P2-item-27
# Consumer 2 consumed: P0-item-24
# Producer 0 produced: P0-item-26Producer 1 produced: P1-item-28
#
# Producer 2 produced: P2-item-28
# Consumer 4 consumed: P1-item-26
# Consumer 0 consumed: P2-item-26
# Producer 0 produced: P0-item-27
# Consumer 1 consumed: P1-item-27
# Producer 1 produced: P1-item-29
# Consumer 3 consumed: P0-item-25
# Consumer 2 consumed: P2-item-27
# Producer 2 produced: P2-item-29
# Producer 0 produced: P0-item-28
# Producer 1 produced: P1-item-30
# Consumer 0 consumed: P0-item-26
# Producer 2 produced: P2-item-30
# Consumer 4 consumed: P1-item-28
# Consumer 1 consumed: P2-item-28
# Consumer 3 consumed: P0-item-27
# Producer 0 produced: P0-item-29
# Consumer 2 consumed: P1-item-29
# Producer 1 produced: P1-item-31
# Producer 2 produced: P2-item-31
# Consumer 0 consumed: P2-item-29
# Consumer 4 consumed: P0-item-28Producer 1 produced: P1-item-32
#
# Consumer 1 consumed: P1-item-30
# Producer 0 produced: P0-item-30
# Producer 2 produced: P2-item-32
# Consumer 3 consumed: P2-item-30
# Consumer 2 consumed: P0-item-29
# Producer 0 produced: P0-item-31
# Producer 1 produced: P1-item-33
# Consumer 0 consumed: P1-item-31
# Producer 2 produced: P2-item-33
# Producer 0 produced: P0-item-32
# Consumer 3 consumed: P2-item-31
# Consumer 4 consumed: P1-item-32
# Producer 1 produced: P1-item-34
# Consumer 1 consumed: P0-item-30
# Producer 2 produced: P2-item-34
# Consumer 2 consumed: P2-item-32
# Producer 0 produced: P0-item-33
# Producer 1 produced: P1-item-35
# Consumer 0 consumed: P0-item-31
# Producer 2 produced: P2-item-35
# Producer 0 produced: P0-item-34
# Consumer 3 consumed: P1-item-33
# Consumer 4 consumed: P2-item-33
# Producer 1 produced: P1-item-36
# Producer 2 produced: P2-item-36
# Consumer 1 consumed: P0-item-32
# Consumer 2 consumed: P1-item-34
# Consumer 0 consumed: P2-item-34
# Producer 0 produced: P0-item-35
# Producer 2 produced: P2-item-37
# Producer 1 produced: P1-item-37
# Consumer 3 consumed: P0-item-33
# Producer 0 produced: P0-item-36
# Consumer 1 consumed: P1-item-35
# Consumer 4 consumed: P2-item-35
# Producer 1 produced: P1-item-38Producer 2 produced: P2-item-38
#
# Consumer 2 consumed: P0-item-34
# Consumer 0 consumed: P1-item-36
# Producer 0 produced: P0-item-37
# Producer 2 produced: P2-item-39
# Consumer 3 consumed: P2-item-36
# Consumer 1 consumed: P0-item-35
# Producer 1 produced: P1-item-39
# Producer 0 produced: P0-item-38
# Consumer 4 consumed: P2-item-37
# Consumer 0 consumed: P1-item-37
# Producer 2 produced: P2-item-40
# Consumer 2 consumed: P0-item-36
# Producer 0 produced: P0-item-39
# Producer 1 produced: P1-item-40
# Producer 2 produced: P2-item-41
# Consumer 1 consumed: P1-item-38
# Consumer 3 consumed: P2-item-38
# Consumer 4 consumed: P0-item-37
# Consumer 0 consumed: P2-item-39
# Consumer 2 consumed: P1-item-39
# Producer 0 produced: P0-item-40
# Producer 1 produced: P1-item-41
# Producer 2 produced: P2-item-42
# Producer 0 produced: P0-item-41Consumer 3 consumed: P0-item-38
#
# Producer 1 produced: P1-item-42
# Consumer 1 consumed: P2-item-40
# Producer 2 produced: P2-item-43
# Consumer 0 consumed: P0-item-39
# Consumer 4 consumed: P1-item-40
# Producer 0 produced: P0-item-42
# Consumer 2 consumed: P2-item-41
# Producer 2 produced: P2-item-44
# Producer 1 produced: P1-item-43
# Producer 0 produced: P0-item-43
# Consumer 3 consumed: P0-item-40
# Producer 0 produced: P0-item-44
# Consumer 1 consumed: P1-item-41
# Consumer 0 consumed: P2-item-42
# Producer 1 produced: P1-item-44
# Consumer 4 consumed: P0-item-41
# Producer 2 produced: P2-item-45
# Consumer 2 consumed: P1-item-42
# Producer 2 produced: P2-item-46Producer 1 produced: P1-item-45
#
# Producer 0 produced: P0-item-45
# Consumer 3 consumed: P2-item-43
# Consumer 0 consumed: P0-item-42
# Consumer 4 consumed: P2-item-44
# Consumer 1 consumed: P1-item-43
# Producer 1 produced: P1-item-46
# Producer 0 produced: P0-item-46
# Producer 2 produced: P2-item-47
# Consumer 2 consumed: P0-item-43
# Producer 1 produced: P1-item-47
# Producer 0 produced: P0-item-47
# Producer 2 produced: P2-item-48
# Consumer 0 consumed: P0-item-44
# Consumer 1 consumed: P1-item-44
# Consumer 3 consumed: P2-item-45
# Producer 1 produced: P1-item-48
# Consumer 4 consumed: P2-item-46
# Producer 0 produced: P0-item-48
# Producer 2 produced: P2-item-49
# Consumer 2 consumed: P1-item-45
# Producer 1 produced: P1-item-49
# Consumer 0 consumed: P0-item-45
# Producer 0 produced: P0-item-49
# Consumer 1 consumed: P1-item-46
# Producer 1 produced: P1-item-50
# Producer 2 produced: P2-item-50
# Consumer 3 consumed: P0-item-46
# Consumer 4 consumed: P2-item-47
# Consumer 2 consumed: P1-item-47
# Producer 0 produced: P0-item-50
# Producer 2 produced: P2-item-51
# Producer 1 produced: P1-item-51
# Consumer 0 consumed: P0-item-47
# Producer 0 produced: P0-item-51
# Consumer 3 consumed: P2-item-48
# Consumer 1 consumed: P1-item-48
# Consumer 4 consumed: P0-item-48
# Producer 2 produced: P2-item-52
# Producer 1 produced: P1-item-52
# Consumer 2 consumed: P2-item-49
# Producer 0 produced: P0-item-52
# Consumer 0 consumed: P1-item-49
# Producer 2 produced: P2-item-53
# Consumer 1 consumed: P0-item-49
# Producer 1 produced: P1-item-53
# Consumer 3 consumed: P1-item-50
# Producer 0 produced: P0-item-53
# Consumer 4 consumed: P2-item-50
# Producer 2 produced: P2-item-54
# Consumer 2 consumed: P0-item-50
# Producer 1 produced: P1-item-54
# Producer 0 produced: P0-item-54
# Consumer 0 consumed: P2-item-51
# Producer 1 produced: P1-item-55
# Producer 2 produced: P2-item-55
# Consumer 4 consumed: P1-item-51
# Consumer 3 consumed: P0-item-51
# Consumer 1 consumed: P2-item-52
# Producer 1 produced: P1-item-56
# Producer 0 produced: P0-item-55
# Producer 2 produced: P2-item-56
# Consumer 2 consumed: P1-item-52
# Consumer 0 consumed: P0-item-52Producer 2 produced: P2-item-57
#
# Producer 1 produced: P1-item-57
# Consumer 4 consumed: P2-item-53
# Producer 0 produced: P0-item-56
# Consumer 3 consumed: P1-item-53
# Consumer 1 consumed: P0-item-53
# Producer 2 produced: P2-item-58
# Producer 1 produced: P1-item-58
# Consumer 2 consumed: P2-item-54
# Producer 2 produced: P2-item-59
# Producer 0 produced: P0-item-57
# Consumer 0 consumed: P1-item-54
# Consumer 4 consumed: P0-item-54
# Producer 1 produced: P1-item-59
# Producer 2 produced: P2-item-60
# Consumer 1 consumed: P1-item-55
# Consumer 3 consumed: P2-item-55
# Producer 0 produced: P0-item-58
# Producer 2 produced: P2-item-61
# Consumer 2 consumed: P1-item-56
# Consumer 4 consumed: P0-item-55
# Producer 1 produced: P1-item-60
# Producer 0 produced: P0-item-59
# Consumer 0 consumed: P2-item-56
# Producer 2 produced: P2-item-62
# Consumer 3 consumed: P2-item-57
# Consumer 1 consumed: P1-item-57
# Producer 0 produced: P0-item-60
# Producer 1 produced: P1-item-61
# Consumer 2 consumed: P0-item-56
# Consumer 4 consumed: P2-item-58
# Producer 2 produced: P2-item-63
# Producer 1 produced: P1-item-62
# Consumer 0 consumed: P1-item-58
# Consumer 3 consumed: P2-item-59
# Producer 0 produced: P0-item-61
# Producer 2 produced: P2-item-64
# Consumer 1 consumed: P0-item-57
# Producer 1 produced: P1-item-63
# Consumer 2 consumed: P1-item-59
# Consumer 4 consumed: P2-item-60
# Producer 0 produced: P0-item-62Producer 2 produced: P2-item-65
#
# Consumer 0 consumed: P0-item-58
# Consumer 3 consumed: P2-item-61
# Producer 1 produced: P1-item-64
# Consumer 1 consumed: P1-item-60
# Consumer 2 consumed: P0-item-59Consumer 4 consumed: P2-item-62
#
# Producer 0 produced: P0-item-63
# Producer 2 produced: P2-item-66
# Producer 1 produced: P1-item-65
# Timer finished, requesting all threads to stop...
# Consumer 3 consumed: P0-item-60
# Consumer 3 stopping...
# Consumer 0 consumed: P1-item-61
# Consumer 0 stopping...
# Producer 0 produced: P0-item-64
# Producer 0 stopping...
# Consumer 1 consumed: P2-item-63
# Consumer 1 stopping...
# Producer 2 produced: P2-item-67
# Producer 2 stopping...
# Producer 1 produced: P1-item-66
# Producer 1 stopping...
# Consumer 2 consumed: P1-item-62
# Consumer 2 stopping...
# Consumer 4 consumed: P0-item-61
# Consumer 4 stopping...
# All threads terminated, program finished.

# %% [markdown]
# ### 3

# %%
import threading
import time

sem1 = threading.Semaphore(1)
sem2 = threading.Semaphore(1)

def thread1():
    sem1.acquire()
    print("Thread 1 acquired sem1")
    time.sleep(1) 
    print("Thread 1 waiting for sem2...")
    sem2.acquire()
    print("Thread 1 acquired sem2")

def thread2():
    sem2.acquire()
    print("Thread 2 acquired sem2")
    time.sleep(1)
    print("Thread 2 waiting for sem1...")
    sem1.acquire()
    print("Thread 2 acquired sem1")

if __name__ == "__main__":
    t1 = threading.Thread(target=thread1)
    t2 = threading.Thread(target=thread2)

    t1.start()
    t2.start()

    time.sleep(5)
    print("Deadlock occurred.")
# Out:
# Thread 1 acquired sem1
# Thread 2 acquired sem2
# Thread 2 waiting for sem1...
# Thread 1 waiting for sem2...
# Deadlock occurred.

# %% [markdown]
# ### 4

# %%
import threading
import time

sem = threading.Semaphore(0)

def P1():
    print('2 seconds sleep to ensure that P2 is not doing anything before P1')
    time.sleep(2)
    print("P1 is running first...")
    time.sleep(2)
    print("P1 finished, releasing semaphore for P2.")
    sem.release()

def P2():
    print("P2 waiting for P1 to finish...")
    sem.acquire()
    print("P2 is now running after P1.")

if __name__ == "__main__":
    t1 = threading.Thread(target=P1)
    t2 = threading.Thread(target=P2)

    t2.start()
    t1.start()

    t1.join()
    t2.join()

    print("P1 finished before P2, as required.")
# Out:
# P2 waiting for P1 to finish...
# 2 seconds sleep to ensure that P2 is not doing anything before P1
# P1 is running first...
# P1 finished, releasing semaphore for P2.
# P2 is now running after P1.
# P1 finished before P2, as required.
